# %%
import pandas as pd

# %%
dataset = pd.read_csv('dataset.csv')
dataset
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
dataset.dropna()
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
dataset.dropna()
dataset.describe()
# Out:
#               year  selling_price     km_driven      mileage       engine  \
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04    19.418783  1458.625016
# std       4.044249   8.062534e+05  5.655055e+04     4.037145   503.916303
# min    1983.000000   2.999900e+04  1.000000e+00     0.000000   624.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04    16.780000  1197.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04    19.300000  1248.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04    22.320000  1582.000000
# max    2020.000000   1.000000e+07  2.360457e+06    42.000000  3604.000000
#
#              seats
# count  7907.000000
# mean      5.416719
# std       0.959588
# min       2.000000
# 25%       5.000000
# 50%       5.000000
# 75%       5.000000
# max      14.000000

# %%
dataset.dtypes
# Out:
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage          float64
# engine           float64
# max_power         object
# torque            object
# seats            float64
# dtype: object

# %%
dataset['seats'] = pd.to_numeric(dataset['seats'], errors='coerce')
dataset = dataset.dropna(subset=['seats'])
dataset['seats'] = dataset['seats'].astype(int)


dataset['max_power'] = pd.to_numeric(dataset['max_power'], errors='coerce')
dataset = dataset.dropna(subset=['max_power'])
dataset['max_power'] = dataset['max_power'].astype(float)

dataset = dataset.drop(['torque'],axis=1)
dataset.dtypes
# Out:
# /var/folders/5v/0lzcxj5x4ks8kyfnvbf83n8w0000gn/T/ipykernel_26698/602273844.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['seats'] = dataset['seats'].astype(int)
# /var/folders/5v/0lzcxj5x4ks8kyfnvbf83n8w0000gn/T/ipykernel_26698/602273844.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['max_power'] = pd.to_numeric(dataset['max_power'], errors='coerce')
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# ...

# %%
dataset
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...
